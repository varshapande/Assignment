# %% [markdown]
# <a href="https://colab.research.google.com/github/varshapande/Assignment/blob/main/Assignment_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd
from urllib.request import urlopen

# %%
url = 'https://jsonblob.com/api/969600459849613312'
response = urlopen(url)
data= json.loads(response.read())
type(data)
# Out:
# dict

# %%
c = data['rider_info']
d = data['maker_response']
d
c
# Out:
# {'2021-11-12-23-26-39-558.jpeg': {'rider_id': '10871699.0',
#   'timestamp': '2021-11-12 23:26:02.049000'},
#  '2021-11-12-23-27-52-175.jpeg': {'rider_id': '11665205.0',
#   'timestamp': '2021-11-12 23:26:52.668000'},
#  '2021-11-12-23-28-24-833.jpeg': {'rider_id': '7374770.0',
#   'timestamp': '2021-11-12 23:26:29.522000'},
#  '2021-11-12-23-28-44-038.jpeg': {'rider_id': '12392356.0',
#   'timestamp': '2021-11-12 23:26:26.710000'},
#  '2021-11-12-23-28-47-705.jpeg': {'rider_id': '10235136.0',
#   'timestamp': '2021-11-12 23:26:07.464000'},
#  '2021-11-12-23-28-49-625.jpeg': {'rider_id': '12173066.0',
#   'timestamp': '2021-11-12 23:28:31.236000'},
#  '2021-11-12-23-28-54-327.jpeg': {'rider_id': '10105740.0',
#   'timestamp': '2021-11-12 23:27:24.602000'},
#  '2021-11-12-23-29-20-002.jpeg': {'rider_id': '9819052.0',
#   'timestamp': '2021-11-12 23:25:57.091000'},
#  '2021-11-12-23-29-46-994.jpeg': {'rider_id': '10698139.0',
#   'timestamp': '2021-11-12 23:28:54.616000'},
#  '2021-11-12-23-30-32-554.jpeg': {'rider_id': '2101723.0',
#   'timestamp': '2021-11-12 23:27:36.817000'},
#  '2021-11-12-23-30-33-222.jpeg': {'rider_id': '10068071.0',
#   'timestamp': '2021-11-12 23:29:28.218000'},
#  '2021-11-12-23-31-48-127.jpeg': {'rider_id': '11501315.0',
#   'timestamp': '2021-11-12 23:30:24.034000'},
#  '2021-11-12-23-31-55-156.jpeg': {'rider_id': '11090435.0',
#   'timestamp': '2021-11-12 23:31:44.824000'},
#  '2021-11-12-23-33-43-836.jpeg': {'rider_id': '3444564.0',
#   'timestamp': '2021-11-12 23:32:32.969000'},
#  '2021-11-12-23-33-46-313.jpeg': {'rider_id': '4766145.0',
#   'timestamp': '2021-11-12 23:32:58.939000'},
#  '2021-11-12-23-34-19-351.jpeg': {'rider_id': '3803112.0',
#   'timestamp': '2021-11-12 23:31:44.223000'},
#  '2021-11-12-23-34-54-798.jpeg': {'rider_id': '12485542.0',
#   'timestamp': '2021-11-12 23:33:09.393000'},
#  '2021-11-12-23-36-04-217.jpeg': {'rider_id': '1892262.0',
#   'timestamp': '2021-11-12 23:32:51.588000'},
#  '2021-11-12-23-39-10-506.jpeg': {'rider_id': '9751964.0',
#   'timestamp': '2021-11-12 23:30:18.612000'},
#  '2021-11-13-09-55-05-662.jpeg': {'rider_id': '6170999.0',
#   'timestamp': '2021-11-12 23:29:33.262000'}}

# %%
def getList(dict):
    list = []
    for key in dict.keys():
        list.append(key)
          
    return list
j= getList(c)
j
# Out:
# ['2021-11-12-23-26-39-558.jpeg',
#  '2021-11-12-23-27-52-175.jpeg',
#  '2021-11-12-23-28-24-833.jpeg',
#  '2021-11-12-23-28-44-038.jpeg',
#  '2021-11-12-23-28-47-705.jpeg',
#  '2021-11-12-23-28-49-625.jpeg',
#  '2021-11-12-23-28-54-327.jpeg',
#  '2021-11-12-23-29-20-002.jpeg',
#  '2021-11-12-23-29-46-994.jpeg',
#  '2021-11-12-23-30-32-554.jpeg',
#  '2021-11-12-23-30-33-222.jpeg',
#  '2021-11-12-23-31-48-127.jpeg',
#  '2021-11-12-23-31-55-156.jpeg',
#  '2021-11-12-23-33-43-836.jpeg',
#  '2021-11-12-23-33-46-313.jpeg',
#  '2021-11-12-23-34-19-351.jpeg',
#  '2021-11-12-23-34-54-798.jpeg',
#  '2021-11-12-23-36-04-217.jpeg',
#  '2021-11-12-23-39-10-506.jpeg',
#  '2021-11-13-09-55-05-662.jpeg']

# %%
def getval(dict):
    list = []
    for value in dict.values():
        list.append(value)
          
    return list
r= getval(c)
r
# Out:
# [{'rider_id': '10871699.0', 'timestamp': '2021-11-12 23:26:02.049000'},
#  {'rider_id': '11665205.0', 'timestamp': '2021-11-12 23:26:52.668000'},
#  {'rider_id': '7374770.0', 'timestamp': '2021-11-12 23:26:29.522000'},
#  {'rider_id': '12392356.0', 'timestamp': '2021-11-12 23:26:26.710000'},
#  {'rider_id': '10235136.0', 'timestamp': '2021-11-12 23:26:07.464000'},
#  {'rider_id': '12173066.0', 'timestamp': '2021-11-12 23:28:31.236000'},
#  {'rider_id': '10105740.0', 'timestamp': '2021-11-12 23:27:24.602000'},
#  {'rider_id': '9819052.0', 'timestamp': '2021-11-12 23:25:57.091000'},
#  {'rider_id': '10698139.0', 'timestamp': '2021-11-12 23:28:54.616000'},
#  {'rider_id': '2101723.0', 'timestamp': '2021-11-12 23:27:36.817000'},
#  {'rider_id': '10068071.0', 'timestamp': '2021-11-12 23:29:28.218000'},
#  {'rider_id': '11501315.0', 'timestamp': '2021-11-12 23:30:24.034000'},
#  {'rider_id': '11090435.0', 'timestamp': '2021-11-12 23:31:44.824000'},
#  {'rider_id': '3444564.0', 'timestamp': '2021-11-12 23:32:32.969000'},
#  {'rider_id': '4766145.0', 'timestamp': '2021-11-12 23:32:58.939000'},
#  {'rider_id': '3803112.0', 'timestamp': '2021-11-12 23:31:44.223000'},
#  {'rider_id': '12485542.0', 'timestamp': '2021-11-12 23:33:09.393000'},
#  {'rider_id': '1892262.0', 'timestamp': '2021-11-12 23:32:51.588000'},
#  {'rider_id': '9751964.0', 'timestamp': '2021-11-12 23:30:18.612000'},
#  {'rider_id': '6170999.0', 'timestamp': '2021-11-12 23:29:33.262000'}]

# %%
for i in range(len(r)):
 del r[i]['timestamp']

# %%
w = r.copy()
w
# Out:
# [{'rider_id': '10871699.0'},
#  {'rider_id': '11665205.0'},
#  {'rider_id': '7374770.0'},
#  {'rider_id': '12392356.0'},
#  {'rider_id': '10235136.0'},
#  {'rider_id': '12173066.0'},
#  {'rider_id': '10105740.0'},
#  {'rider_id': '9819052.0'},
#  {'rider_id': '10698139.0'},
#  {'rider_id': '2101723.0'},
#  {'rider_id': '10068071.0'},
#  {'rider_id': '11501315.0'},
#  {'rider_id': '11090435.0'},
#  {'rider_id': '3444564.0'},
#  {'rider_id': '4766145.0'},
#  {'rider_id': '3803112.0'},
#  {'rider_id': '12485542.0'},
#  {'rider_id': '1892262.0'},
#  {'rider_id': '9751964.0'},
#  {'rider_id': '6170999.0'}]

# %%
for i in w:
  dict(i)
  print(i)
  newdic = i
# Out:
# {'rider_id': '10871699.0'}
# {'rider_id': '11665205.0'}
# {'rider_id': '7374770.0'}
# {'rider_id': '12392356.0'}
# {'rider_id': '10235136.0'}
# {'rider_id': '12173066.0'}
# {'rider_id': '10105740.0'}
# {'rider_id': '9819052.0'}
# {'rider_id': '10698139.0'}
# {'rider_id': '2101723.0'}
# {'rider_id': '10068071.0'}
# {'rider_id': '11501315.0'}
# {'rider_id': '11090435.0'}
# {'rider_id': '3444564.0'}
# {'rider_id': '4766145.0'}
# {'rider_id': '3803112.0'}
# {'rider_id': '12485542.0'}
# {'rider_id': '1892262.0'}
# {'rider_id': '9751964.0'}
# {'rider_id': '6170999.0'}

# %%
print(newdic)
type(newdic)
# Out:
# {'rider_id': '6170999.0'}
# dict

# %%
y = d['video2d']['data']['annotations']
z = y[0]['frames']

# %%
c = {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac'}
type(c)
# Out:
# dict

# %%
def getList(dict):
    list = []
    for key in dict.keys():
        list.append(key)
          
    return list
y = getList(z)
y
# Out:
# ['2021-11-12-23-26-39-558.jpeg',
#  '2021-11-12-23-27-52-175.jpeg',
#  '2021-11-12-23-28-24-833.jpeg',
#  '2021-11-12-23-28-44-038.jpeg',
#  '2021-11-12-23-28-47-705.jpeg',
#  '2021-11-12-23-28-49-625.jpeg',
#  '2021-11-12-23-28-54-327.jpeg',
#  '2021-11-12-23-29-20-002.jpeg',
#  '2021-11-12-23-29-46-994.jpeg',
#  '2021-11-12-23-30-32-554.jpeg',
#  '2021-11-12-23-30-33-222.jpeg',
#  '2021-11-12-23-31-48-127.jpeg',
#  '2021-11-12-23-31-55-156.jpeg',
#  '2021-11-12-23-33-43-836.jpeg',
#  '2021-11-12-23-33-46-313.jpeg',
#  '2021-11-12-23-34-19-351.jpeg',
#  '2021-11-12-23-34-54-798.jpeg',
#  '2021-11-12-23-36-04-217.jpeg',
#  '2021-11-12-23-39-10-506.jpeg',
#  '2021-11-13-09-55-05-662.jpeg']

# %%
def getval(dict):
    list = []
    for value in dict.values():
        list.append(value)
          
    return list
k= getval(z)
k
# Out:
# [{'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '938a090a-37e8-408d-853e-966670bfc5a8',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '1ef21568-e148-4317-a00f-b0f6f372794a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '249c3ce0-667d-430c-8d40-d96cd775af2f',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'}]

# %%
map = zip(y,k)
mppp = dict(map)
mppp
# Out:
# {'2021-11-12-23-26-39-558.jpeg': {'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-27-52-175.jpeg': {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-24-833.jpeg': {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-44-038.jpeg': {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-47-705.jpeg': {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-49-625.jpeg': {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-54-327.jpeg': {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-29-20-002.jpeg': {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-29-46-994.jpeg': {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-30-32-554.jpeg': {'_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-30-33-222.jpeg': {'_id': '938a090a-37e8-408d-853e-966670bfc5a8',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-31-48-127.jpeg': {'_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-31-55-156.jpeg': {'_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-33-43-836.jpeg': {'_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-33-46-313.jpeg': {'_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-34-19-351.jpeg': {'_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-34-54-798.jpeg': {'_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-36-04-217.jpeg': {'_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-39-10-506.jpeg': {'_id': '1ef21568-e148-4317-a00f-b0f6f372794a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-13-09-55-05-662.jpeg': {'_id': '249c3ce0-667d-430c-8d40-d96cd775af2f',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'}}

# %%
dictkey = list(k[1].keys())
print(dictkey)
del_key =list( ['color','origin','evaluations','shapeEditable','showLabel','labelEditable','keyFrame','evaluations','annotationQcEvals','annotationQCEvaluations'])
# Out:
# ['_id', 'type', 'color', 'label', 'origin', 'points', 'comments', 'keyFrame', 'showLabel', 'attributes', 'evaluations', 'labelEditable', 'shapeEditable', 'annotationQcEvals', 'annotationQCEvaluations']

# %%
delkey = 'origin'

# %%
#for i in range(len(k)):
  #del k[i]['color']
  #del k[i]['origin']
  #del k[i]['comments']
  #del k[i]['evaluations']
  #del k[i]['shapeEditable']
 # del k[i]['showLabel']
  #del k[i]['labelEditable']
  #del k[i]['keyFrame']
  ##del k[i]['evaluations']
  #del k[i]['annotationsQcEvals']
  #del k[i]['annotationQCEvaluations']

# %%
res = [{key : val for key, val in sub.items() if key != 'origin'} for sub in k]
res1 = [{key : val for key, val in sub.items() if key != 'color'} for sub in res]
res2 = [{key : val for key, val in sub.items() if key != 'comments'} for sub in res1]
res3 = [{key : val for key, val in sub.items() if key !='keyFrame'} for sub in res2]
res4 = [{key : val for key, val in sub.items() if key != 'showLabel'} for sub in res3]
res5 = [{key : val for key, val in sub.items() if key != 'evaluations'} for sub in res4]
res6 = [{key : val for key, val in sub.items() if key != 'labelEditable'} for sub in res5]
res7 = [{key : val for key, val in sub.items() if key != 'shapeEditable'} for sub in res6]
res8 = [{key : val for key, val in sub.items() if key != 'annotationQCEvaluations' } for sub in res7]
res9 = [{key : val for key, val in sub.items() if key != 'annotationQcEvals'} for sub in res8]
res = [{key : val for key, val in sub.items() if key != delkey} for sub in k]
res = [{key : val for key, val in sub.items() if key != delkey} for sub in k]
res = [{key : val for key, val in sub.items() if key != delkey} for sub in k]
 
for i in res9:
  print(i)
# Out:
# {'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '938a090a-37e8-408d-853e-966670bfc5a8', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '1ef21568-e148-4317-a00f-b0f6f372794a', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}
# {'_id': '249c3ce0-667d-430c-8d40-d96cd775af2f', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}

# %%
print(res9)
type(res9)
# Out:
# [{'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': '938a090a-37e8-408d-853e-966670bfc5a8', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}}, {'_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes ...
# list

# %%
map = zip(y,res9)
mppp = dict(map)
mppp
# Out:
# {'2021-11-12-23-26-39-558.jpeg': {'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-27-52-175.jpeg': {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-28-24-833.jpeg': {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-28-44-038.jpeg': {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-28-47-705.jpeg': {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-28-49-625.jpeg': {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-28-54-327.jpeg': {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-29-20-002.jpeg': {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-29-46-994.jpeg': {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-30-32-554.jpeg': {'_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-30-33-222.jpeg': {'_id': '938a090a-37e8-408d-853e-966670bfc5a8',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-31-48-127.jpeg': {'_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-31-55-156.jpeg': {'_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-33-43-836.jpeg': {'_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-33-46-313.jpeg': {'_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-34-19-351.jpeg': {'_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-34-54-798.jpeg': {'_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-36-04-217.jpeg': {'_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-39-10-506.jpeg': {'_id': '1ef21568-e148-4317-a00f-b0f6f372794a',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-13-09-55-05-662.jpeg': {'_id': '249c3ce0-667d-430c-8d40-d96cd775af2f',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'}}

# %%
for key in mppp.keys():
  for keys,value in newdic.items():
      mppp[key][keys] = value

# %%
for key in mppp.keys():
  for keys,value in c.items():
      mppp[key][keys] = value

# %%
mppp
# Out:
# {'2021-11-12-23-26-39-558.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-27-52-175.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-28-24-833.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '0428a498-8722-4080-bbe9-e2e1e5354811',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-28-44-038.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-28-47-705.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '88eb3770-6815-4f05-98ab-73d1d497382a',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-28-49-625.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '8495ad70-c704-47e2-8d4f-54347270ed5a',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-28-54-327.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': 'e3772232-e680-4fdb-895c-6d629be6c98b',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-29-20-002.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': 'eac3a066-ecc5-46ba-9866-532aa7961674',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-29-46-994.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '7d4f623a-b8f7-4421-aa97-841650056ab1',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-30-32-554.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-30-33-222.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '938a090a-37e8-408d-853e-966670bfc5a8',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-31-48-127.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-31-55-156.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-33-43-836.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-33-46-313.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-34-19-351.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-34-54-798.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-36-04-217.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-12-23-39-10-506.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '1ef21568-e148-4317-a00f-b0f6f372794a',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'},
#  '2021-11-13-09-55-05-662.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#   '_id': '249c3ce0-667d-430c-8d40-d96cd775af2f',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'rider_id': '6170999.0',
#   'type': 'landmark'}}

# %%
dict_1 = {'frames':mppp}
dict_1
# Out:
# {'frames': {'2021-11-12-23-26-39-558.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-27-52-175.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-28-24-833.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '0428a498-8722-4080-bbe9-e2e1e5354811',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-28-44-038.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-28-47-705.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '88eb3770-6815-4f05-98ab-73d1d497382a',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-28-49-625.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '8495ad70-c704-47e2-8d4f-54347270ed5a',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-28-54-327.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': 'e3772232-e680-4fdb-895c-6d629be6c98b',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-29-20-002.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': 'eac3a066-ecc5-46ba-9866-532aa7961674',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-29-46-994.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '7d4f623a-b8f7-4421-aa97-841650056ab1',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-30-32-554.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-30-33-222.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '938a090a-37e8-408d-853e-966670bfc5a8',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-31-48-127.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-31-55-156.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-33-43-836.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-33-46-313.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-34-19-351.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-34-54-798.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-36-04-217.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-12-23-39-10-506.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '1ef21568-e148-4317-a00f-b0f6f372794a',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'},
#   '2021-11-13-09-55-05-662.jpeg': {'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#    '_id': '249c3ce0-667d-430c-8d40-d96cd775af2f',
#    'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#     'waering_mask': {'state': 'editable', 'value': 'yes'},
#     'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#    'label': 'rider_classification',
#    'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#    'rider_id': '6170999.0',
#    'type': 'landmark'}}}

# %%
dict_2 = {'export_data' :{'annotations':{}}}
dict_2['export_data']['annotations'] = dict_1

# %% [markdown]
# ##dict_2 is final

# %%
print(dict_2)
# Out:
# {'export_data': {'annotations': {'frames': {'2021-11-12-23-26-39-558.jpeg': {'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}, 'rider_id': '6170999.0', 'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac'}, '2021-11-12-23-27-52-175.jpeg': {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}, 'rider_id': '6170999.0', 'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac'}, '2021-11-12-23-28-24-833.jpeg': {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}, 'rider_id': '6170999.0', 'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac'}, '2021-11-12-23-28-44-038.jpeg': {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}, 'rider_id': '6170999.0', 'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac'}, '2021-11-12-23-28-47-705.jpeg': {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}, 'rider_id': '6170999.0', 'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac'}, '2021-11-12-23-28-49-625.jpeg': {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'no'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}, 'rider_id': '6170999.0', 'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac'}, '2021-11-12-23-28-54-327.jpeg': {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}, 'rider_id': '6170999.0', 'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac'}, '2021-11-12-23-29-20-002.jpeg': {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}, 'rider_id': '6170999.0', 'Tracker_id': '781db9b8-5c3f-4e56-8946-c639c52719ac'}, '2021-11-12-23-29-46-994.jpeg': {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1', 'type': 'landmark', 'label': 'rider_classification', 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value':  ...
