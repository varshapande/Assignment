# %% [markdown]
# <a href="https://colab.research.google.com/github/varshapande/Assignment/blob/main/part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd
from urllib.request import urlopen

# %%
url = 'https://jsonblob.com/api/969600459849613312'
response = urlopen(url)
data= json.loads(response.read())
type(data)
# Out:
# dict

# %%
data
# Out:
# {'maker_response': {'video2d': {'data': {'annotations': [{'_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#       'attributes': None,
#       'color': 'rgb(226, 220, 99)',
#       'evaluations': None,
#       'frames': {'2021-11-12-23-26-39-558.jpeg': {'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#         'annotationQCEvaluations': None,
#         'annotationQcEvals': {},
#         'attributes': {'selfie_validity': {'state': 'editable',
#           'value': 'valid'},
#          'waering_mask': {'state': 'editable', 'value': 'yes'},
#          'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#         'color': None,
#         'comments': [],
#         'evaluations': {},
#         'keyFrame': False,
#         'label': 'rider_classification',
#         'labelEditable': False,
#         'origin': None,
#         'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#         'shapeEditable': False,
#         'showLabel': False,
#         'type': 'landmark'},
# ...

# %%
y = data['maker_response'] ['video2d']['data']['annotations']
y
z = y[0]['frames']
ls = []
for i,j in z.items():
  ls.append(j)
  print(ls)
# Out:
# [{'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779', 'type': 'landmark', 'color': None, 'label': 'rider_classification', 'origin': None, 'points': {'p1': {'x': 0, 'y': 0, 'label': '1'}}, 'comments': [], 'keyFrame': False, 'showLabel': False, 'attributes': {'waering_mask': {'state': 'editable', 'value': 'yes'}, 'wearing_shirt': {'state': 'editable', 'value': 'yes'}, 'selfie_validity': {'state': 'editable', 'value': 'valid'}}, 'evaluations': {}, 'labelEditable': False, 'shapeEditable': False, 'annotationQcEvals': {}, 'annotationQCEvaluations': None}]
# ...

# %%
h = []
for i in range(len(ls)):
       h.append(ls[0]['_id'])
print(h)
# Out:
# ['25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779', '25786763-b2d7-4285-a4fc-9aba87ddd779']

# %%
Label = 'rider_classifiction'
Frame_id = h
Tracker_id = '781db9b8-5c3f-4e56-8946-c639c52719ac'

# %%
lt = []
for i in range(len(ls)):
   lt.append(Label)
print(lt)
# Out:
# ['rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction']

# %%
gt = []
for i in range(len(ls)):
   gt.append(Tracker_id)
print(lt)
# Out:
# ['rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction', 'rider_classifiction']

# %%
dictn = {'frame_id': Frame_id, 'tracker_id': Tracker_id , 'label': Label}

# %%
df = pd.DataFrame(dictn)
df
# Out:
#                                 frame_id  \
# 0   25786763-b2d7-4285-a4fc-9aba87ddd779
# 1   25786763-b2d7-4285-a4fc-9aba87ddd779
# 2   25786763-b2d7-4285-a4fc-9aba87ddd779
# 3   25786763-b2d7-4285-a4fc-9aba87ddd779
# 4   25786763-b2d7-4285-a4fc-9aba87ddd779
# 5   25786763-b2d7-4285-a4fc-9aba87ddd779
# 6   25786763-b2d7-4285-a4fc-9aba87ddd779
# 7   25786763-b2d7-4285-a4fc-9aba87ddd779
# 8   25786763-b2d7-4285-a4fc-9aba87ddd779
# 9   25786763-b2d7-4285-a4fc-9aba87ddd779
# 10  25786763-b2d7-4285-a4fc-9aba87ddd779
# 11  25786763-b2d7-4285-a4fc-9aba87ddd779
# 12  25786763-b2d7-4285-a4fc-9aba87ddd779
# 13  25786763-b2d7-4285-a4fc-9aba87ddd779
# 14  25786763-b2d7-4285-a4fc-9aba87ddd779
# 15  25786763-b2d7-4285-a4fc-9aba87ddd779
# 16  25786763-b2d7-4285-a4fc-9aba87ddd779
# 17  25786763-b2d7-4285-a4fc-9aba87ddd779
# 18  25786763-b2d7-4285-a4fc-9aba87ddd779
# 19  25786763-b2d7-4285-a4fc-9aba87ddd779
#
#                               tracker_id                label
# ...

# %%
dh = df.to_csv('datatocsv.csv')
dh

# %%
do = pd.read_csv('/content/datatocsv.csv')
do
# Out:
#     Unnamed: 0                              frame_id  \
# 0            0  25786763-b2d7-4285-a4fc-9aba87ddd779
# 1            1  25786763-b2d7-4285-a4fc-9aba87ddd779
# 2            2  25786763-b2d7-4285-a4fc-9aba87ddd779
# 3            3  25786763-b2d7-4285-a4fc-9aba87ddd779
# 4            4  25786763-b2d7-4285-a4fc-9aba87ddd779
# 5            5  25786763-b2d7-4285-a4fc-9aba87ddd779
# 6            6  25786763-b2d7-4285-a4fc-9aba87ddd779
# 7            7  25786763-b2d7-4285-a4fc-9aba87ddd779
# 8            8  25786763-b2d7-4285-a4fc-9aba87ddd779
# 9            9  25786763-b2d7-4285-a4fc-9aba87ddd779
# 10          10  25786763-b2d7-4285-a4fc-9aba87ddd779
# 11          11  25786763-b2d7-4285-a4fc-9aba87ddd779
# 12          12  25786763-b2d7-4285-a4fc-9aba87ddd779
# 13          13  25786763-b2d7-4285-a4fc-9aba87ddd779
# 14          14  25786763-b2d7-4285-a4fc-9aba87ddd779
# 15          15  25786763-b2d7-4285-a4fc-9aba87ddd779
# 16          16  25786763-b2d7-4285-a4fc-9aba87ddd779
# ...
