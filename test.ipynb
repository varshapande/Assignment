# %% [markdown]
# <a href="https://colab.research.google.com/github/varshapande/Assignment/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd
from urllib.request import urlopen

# %%
url = 'https://jsonblob.com/api/969600459849613312'
response = urlopen(url)
data= json.loads(response.read())
type(data)
# Out:
# dict

# %%
b = json.dumps(data)
b
# Out:
# '{"rider_info": {"2021-11-12-23-26-39-558.jpeg": {"rider_id": "10871699.0", "timestamp": "2021-11-12 23:26:02.049000"}, "2021-11-12-23-27-52-175.jpeg": {"rider_id": "11665205.0", "timestamp": "2021-11-12 23:26:52.668000"}, "2021-11-12-23-28-24-833.jpeg": {"rider_id": "7374770.0", "timestamp": "2021-11-12 23:26:29.522000"}, "2021-11-12-23-28-44-038.jpeg": {"rider_id": "12392356.0", "timestamp": "2021-11-12 23:26:26.710000"}, "2021-11-12-23-28-47-705.jpeg": {"rider_id": "10235136.0", "timestamp": "2021-11-12 23:26:07.464000"}, "2021-11-12-23-28-49-625.jpeg": {"rider_id": "12173066.0", "timestamp": "2021-11-12 23:28:31.236000"}, "2021-11-12-23-28-54-327.jpeg": {"rider_id": "10105740.0", "timestamp": "2021-11-12 23:27:24.602000"}, "2021-11-12-23-29-20-002.jpeg": {"rider_id": "9819052.0", "timestamp": "2021-11-12 23:25:57.091000"}, "2021-11-12-23-29-46-994.jpeg": {"rider_id": "10698139.0", "timestamp": "2021-11-12 23:28:54.616000"}, "2021-11-12-23-30-32-554.jpeg": {"rider_id": "2101723.0", "timestamp": "2021-11-12 23:27:36.817000"}, "2021-11-12-23-30-33-222.jpeg": {"rider_id": "10068071.0", "timestamp": "2021-11-12 23:29:28.218000"}, "2021-11-12-23-31-48-127.jpeg": {"rider_id": "11501315.0", "timestamp": "2021-11-12 23:30:24.034000"}, "2021-11-12-23-31-55-156.jpeg": {"rider_id": "11090435.0", "timestamp": "2021-11-12 23:31:44.824000"}, "2021-11-12-23-33-43-836.jpeg": {"rider_id": "3444564.0", "timestamp": "2021-11-12 23:32:32.969000"}, "2021-11-12-23-33-46-313.jpeg": {"rider_id": "4766145.0", "timestamp": "2021-11-12 23:32:58.939000"}, "2021-11-12-23-34-19-351.jpeg": {"rider_id": "3803112.0", "timestamp": "2021-11-12 23:31:44.223000"}, "2021-11-12-23-34-54-798.jpeg": {"rider_id": "12485542.0", "timestamp": "2021-11-12 23:33:09.393000"}, "2021-11-12-23-36-04-217.jpeg": {"rider_id": "1892262.0", "timestamp": "2021-11-12 23:32:51.588000"}, "2021-11-12-23-39-10-506.jpeg": {"rider_id": "9751964.0", "timestamp": "2021-11-12 23:30:18.612000"}, "2021-11-13-09-55-05-662.jpeg": {"rider_id": "6170999.0", "timestamp": "2021-11-12 23:29:33.262000"}}, "video_data": {"frames": [{"_id": "00000000-0000-0000-0000-000000000000", "src": "http://d5g2iurv6azza.cloudfront.net/cl/d199654a-fb41-4910-b393-f5e7b31a1407/pr/71808ca2-eb42-4d6f-9732-4d0e5705c819/bt/31092c34-2995-427e-96f9-e638f7c59daf/jb/52aaca54-ff3e-41c1-a5f0-4ef60a44cffb/validated_data/dd60d605-7e78-4971-9a85-f8ce547af67f", "ref_id": "", "frame_id": "2021-11-12-23-34-54-798.jpeg", "meta_data": null, "src_original": "https://storage.googleapis.com/prod-partner-images/2021-11-12-23-34-54-798.jpeg"}, {"_id": "00000000-0000-0000-0000-000000000000", "src": "http://d5g2iurv6azza.cloudfront.net/cl/d199654a-fb41-4910-b393-f5e7b31a1407/pr/71808ca2-eb42-4d6f-9732-4d0e5705c819/bt/31092c34-2995-427e-96f9-e638f7c59daf/jb/52aaca54-ff3e-41c1-a5f0-4ef60a44cffb/validated_data/07ed11ad-11ad-4c07-952e-d334b6e22801", "ref_id": "", "frame_id": "2021-11-12-23-33-46-313.jpeg", "meta_data": null, "src_original": "https://storage.googleapis.com/prod-partner-images/2021-11-12-23-33-46-313.jpeg"}, {"_id": "00000000-0000-0000-0000-000000000000", "src": "http://d5g2iurv6azza.cloudfront.net/cl/d199654a-fb41-4910-b393-f5e7b31a1407/pr/71808ca2-eb42-4d6f-9732-4d0e5705c819/bt/31092c34-2995-427e-96f9-e638f7c59daf/jb/52aaca54-ff3e-41c1-a5f0-4ef60a44cffb/validated_data/e507403b-7ac5-493c-b488-f423b9c47bf1", "ref_id": "", "frame_id": "2021-11-12-23-36-04-217.jpeg", "meta_data": null, "src_original": "https://storage.googleapis.com/prod-partner-images/2021-11-12-23-36-04-217.jpeg"}, {"_id": "00000000-0000-0000-0000-000000000000", "src": "http://d5g2iurv6azza.cloudfront.net/cl/d199654a-fb41-4910-b393-f5e7b31a1407/pr/71808ca2-eb42-4d6f-9732-4d0e5705c819/bt/31092c34-2995-427e-96f9-e638f7c59daf/jb/52aaca54-ff3e-41c1-a5f0-4ef60a44cffb/validated_data/84287925-5a03-477d-89e9-98ba926dbd27", "ref_id": "", "frame_id": "2021-11-12-23-33-43-836.jpeg", "meta_data": null, "src_original": "https://storage.googleapis.com/prod-partner-images/2021- ...

# %%
c = data['rider_info']
d = data['maker_response']
d
# Out:
# {'video2d': {'data': {'annotations': [{'_id': '781db9b8-5c3f-4e56-8946-c639c52719ac',
#      'attributes': None,
#      'color': 'rgb(226, 220, 99)',
#      'evaluations': None,
#      'frames': {'2021-11-12-23-26-39-558.jpeg': {'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-27-52-175.jpeg': {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-28-24-833.jpeg': {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-28-44-038.jpeg': {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-28-47-705.jpeg': {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-28-49-625.jpeg': {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-28-54-327.jpeg': {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-29-20-002.jpeg': {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-29-46-994.jpeg': {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-30-32-554.jpeg': {'_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-30-33-222.jpeg': {'_id': '938a090a-37e8-408d-853e-966670bfc5a8',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-31-48-127.jpeg': {'_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-31-55-156.jpeg': {'_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-33-43-836.jpeg': {'_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-33-46-313.jpeg': {'_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-34-19-351.jpeg': {'_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-34-54-798.jpeg': {'_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-36-04-217.jpeg': {'_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-12-23-39-10-506.jpeg': {'_id': '1ef21568-e148-4317-a00f-b0f6f372794a',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'},
#       '2021-11-13-09-55-05-662.jpeg': {'_id': '249c3ce0-667d-430c-8d40-d96cd775af2f',
#        'annotationQCEvaluations': None,
#        'annotationQcEvals': {},
#        'attributes': {'selfie_validity': {'state': 'editable',
#          'value': 'valid'},
#         'waering_mask': {'state': 'editable', 'value': 'yes'},
#         'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#        'color': None,
#        'comments': [],
#        'evaluations': {},
#        'keyFrame': False,
#        'label': 'rider_classification',
#        'labelEditable': False,
#        'origin': None,
#        'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#        'shapeEditable': False,
#        'showLabel': False,
#        'type': 'landmark'}},
#      'grouping_config': None,
#      'label': 'rider_classification',
#      'label_id': None,
#      'origin': None,
#      'source': 'images',
#      'state': 'editable',
#      'type': 'landmark'}],
#    'groups': None},
#   'success': True,
#   'type': 'video2d'}}

# %%
y = d['video2d']['data']['annotations']
z = y[0]['frames']
z
# Out:
# {'2021-11-12-23-26-39-558.jpeg': {'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-27-52-175.jpeg': {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-24-833.jpeg': {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-44-038.jpeg': {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-47-705.jpeg': {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-49-625.jpeg': {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-54-327.jpeg': {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-29-20-002.jpeg': {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-29-46-994.jpeg': {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-30-32-554.jpeg': {'_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-30-33-222.jpeg': {'_id': '938a090a-37e8-408d-853e-966670bfc5a8',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-31-48-127.jpeg': {'_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-31-55-156.jpeg': {'_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-33-43-836.jpeg': {'_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-33-46-313.jpeg': {'_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-34-19-351.jpeg': {'_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-34-54-798.jpeg': {'_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-36-04-217.jpeg': {'_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-39-10-506.jpeg': {'_id': '1ef21568-e148-4317-a00f-b0f6f372794a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-13-09-55-05-662.jpeg': {'_id': '249c3ce0-667d-430c-8d40-d96cd775af2f',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'}}

# %%
def getList(dict):
    list = []
    for key in dict.keys():
        list.append(key)
          
    return list
y = getList(z)
y
# Out:
# ['2021-11-12-23-26-39-558.jpeg',
#  '2021-11-12-23-27-52-175.jpeg',
#  '2021-11-12-23-28-24-833.jpeg',
#  '2021-11-12-23-28-44-038.jpeg',
#  '2021-11-12-23-28-47-705.jpeg',
#  '2021-11-12-23-28-49-625.jpeg',
#  '2021-11-12-23-28-54-327.jpeg',
#  '2021-11-12-23-29-20-002.jpeg',
#  '2021-11-12-23-29-46-994.jpeg',
#  '2021-11-12-23-30-32-554.jpeg',
#  '2021-11-12-23-30-33-222.jpeg',
#  '2021-11-12-23-31-48-127.jpeg',
#  '2021-11-12-23-31-55-156.jpeg',
#  '2021-11-12-23-33-43-836.jpeg',
#  '2021-11-12-23-33-46-313.jpeg',
#  '2021-11-12-23-34-19-351.jpeg',
#  '2021-11-12-23-34-54-798.jpeg',
#  '2021-11-12-23-36-04-217.jpeg',
#  '2021-11-12-23-39-10-506.jpeg',
#  '2021-11-13-09-55-05-662.jpeg']

# %%
def getval(dict):
    list = []
    for value in dict.values():
        list.append(value)
          
    return list
k = getval(z)
k
# Out:
# [{'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '938a090a-37e8-408d-853e-966670bfc5a8',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '1ef21568-e148-4317-a00f-b0f6f372794a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  {'_id': '249c3ce0-667d-430c-8d40-d96cd775af2f',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'}]

# %%
map = zip(y,k)
mppp = dict(map)
mppp
# Out:
# {'2021-11-12-23-26-39-558.jpeg': {'_id': '25786763-b2d7-4285-a4fc-9aba87ddd779',
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'label': 'rider_classification',
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'type': 'landmark'},
#  '2021-11-12-23-27-52-175.jpeg': {'_id': 'b12b3e0b-9f7b-41fa-9d15-6b482cd5472d',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-24-833.jpeg': {'_id': '0428a498-8722-4080-bbe9-e2e1e5354811',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-44-038.jpeg': {'_id': 'aaa1e078-28eb-4858-874f-832c9a6a35bf',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-47-705.jpeg': {'_id': '88eb3770-6815-4f05-98ab-73d1d497382a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-49-625.jpeg': {'_id': '8495ad70-c704-47e2-8d4f-54347270ed5a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-28-54-327.jpeg': {'_id': 'e3772232-e680-4fdb-895c-6d629be6c98b',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-29-20-002.jpeg': {'_id': 'eac3a066-ecc5-46ba-9866-532aa7961674',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-29-46-994.jpeg': {'_id': '7d4f623a-b8f7-4421-aa97-841650056ab1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-30-32-554.jpeg': {'_id': '93c1c23a-0733-4a32-b15b-cdc6bf4d2836',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-30-33-222.jpeg': {'_id': '938a090a-37e8-408d-853e-966670bfc5a8',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-31-48-127.jpeg': {'_id': 'eda2c620-6249-4bab-8b54-08c98ba77c37',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-31-55-156.jpeg': {'_id': '0bacf8bd-36c9-4f11-95bb-89ab89619592',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-33-43-836.jpeg': {'_id': 'f3904814-700c-49a6-913c-6d5e4dfc3b34',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-33-46-313.jpeg': {'_id': '702a02b6-26ef-4ba1-a6bb-41cc660009a2',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'no'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-34-19-351.jpeg': {'_id': '6be5ac26-640e-428e-bbb5-83ef5d84a6dd',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-34-54-798.jpeg': {'_id': 'ee63192c-debc-4870-94b9-f7b7b3b89232',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-36-04-217.jpeg': {'_id': 'f084c4f9-080a-4a3f-8923-3e9040f146c1',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-12-23-39-10-506.jpeg': {'_id': '1ef21568-e148-4317-a00f-b0f6f372794a',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'},
#  '2021-11-13-09-55-05-662.jpeg': {'_id': '249c3ce0-667d-430c-8d40-d96cd775af2f',
#   'annotationQCEvaluations': None,
#   'annotationQcEvals': {},
#   'attributes': {'selfie_validity': {'state': 'editable', 'value': 'valid'},
#    'waering_mask': {'state': 'editable', 'value': 'yes'},
#    'wearing_shirt': {'state': 'editable', 'value': 'yes'}},
#   'color': None,
#   'comments': [],
#   'evaluations': {},
#   'keyFrame': False,
#   'label': 'rider_classification',
#   'labelEditable': False,
#   'origin': None,
#   'points': {'p1': {'label': '1', 'x': 0, 'y': 0}},
#   'shapeEditable': False,
#   'showLabel': False,
#   'type': 'landmark'}}

# %%
dictkey = k[1].keys()
dictkey
del_key =list( ['color','origin','evaluations'])

# %%
for items in y:
    if del_key  in items:
        del items([del_key])
# Out:
#   File "<ipython-input-78-3f5465370ec1>", line 3
#     del items([del_key])
#        ^
# SyntaxError: can't delete function call
